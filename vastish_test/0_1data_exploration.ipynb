# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
seis = np.load('seismic_data.npy')
porosity = np.load('porosity_data.npy')

# %%
seis
# Out:
# array([[-0.04300714, -0.0465951 , -0.0486302 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.0608418 ,  0.06770571,  0.07199007, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.07756672, -0.10552307, -0.13023612, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.04868347, -0.02426392,  0.00138399, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.07347785, -0.08890852, -0.10177633, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.08056513, -0.08594679, -0.08740475, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
plt.plot(seis[1,:])

# %%
len(seis[1,:])
# Out:
# 246

# %%
seis[1,:]
# Out:
# array([ 6.08418019e-02,  6.77057096e-02,  7.19900723e-02,  7.27798293e-02,
#         7.13625853e-02,  6.65688454e-02,  5.83876900e-02,  4.81465827e-02,
#         3.51325191e-02,  2.27327252e-02,  9.97402698e-03, -2.64800309e-03,
#        -1.37957218e-02, -2.32266497e-02, -3.06627778e-02, -3.76748871e-02,
#        -4.06906638e-02, -4.24676725e-02, -4.31300169e-02, -4.28669820e-02,
#        -4.17014220e-02, -3.90225231e-02, -3.60979082e-02, -3.13892338e-02,
#        -2.52147516e-02, -1.78389744e-02, -8.99776243e-03,  8.82197171e-04,
#         1.13496501e-02,  2.25563268e-02,  3.35007316e-02,  4.20009367e-02,
#         4.86271967e-02,  5.26247242e-02,  5.31849107e-02,  5.04199072e-02,
#         4.30785666e-02,  3.18870494e-02,  2.06869072e-02,  6.47155186e-03,
#        -6.29839324e-03, -2.15916834e-02, -3.46932376e-02, -4.66844834e-02,
#        -5.46649968e-02, -6.14343449e-02, -6.49406793e-02, -6.74108194e-02,
# ...

# %% [markdown]
# ![](attachment:image.png)
