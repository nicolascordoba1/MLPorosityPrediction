# %% [markdown]
# # Import libraries

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import numpy as np
from random import randint
from sklearn.metrics import mean_squared_error
#from wiggle.wiggle import wiggle
from matplotlib.pyplot import figure
import math
import tensorflow as tf
#import tensorflow_probability as tfp
#import tensorflow_addons as tfa
from tensorflow.keras import regularizers
from keras.layers import Activation, BatchNormalization, Conv1D, LeakyReLU
from keras import initializers


from sklearn import model_selection
# Out:
# 2024-05-18 11:18:29.591397: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-18 11:18:29.591475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-18 11:18:29.669522: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-18 11:18:29.839218: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-18 11:18:31.317979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
epocas=500

# %%
def visualizacion_resultados(history):
    epochs = [i for i in range(epocas)]

    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    train_lr = history.history['lr']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    

    fig, ax = plt.subplots(1,3)
    fig.set_size_inches(16,7)

    ax[0].plot(epochs, train_acc, 'go-', label='accuracy-train')
    ax[0].plot(epochs, val_acc, 'ro-', label='accuracy-val')
    ax[0].set_title('Accuracy train')
    ax[0].legend()
    ax[0].set_xlabel('epochs')
    ax[0].set_ylabel('accuracy')

    ax[1].plot(epochs, train_loss, 'go-', label='loss-train')
    ax[1].plot(epochs, val_loss, 'ro-', label='loss-val')
    ax[1].set_title('Loss train')
    ax[1].legend()
    ax[1].set_xlabel('epochs')
    ax[1].set_ylabel('loss')
    
    ax[2].plot(epochs, train_lr, 'go-', label='lr-train')
    ax[2].set_title('Learning Rate train')
    ax[2].legend()
    ax[2].set_xlabel('epochs')
    ax[2].set_ylabel('Learning Rate')
    
    fig.savefig('./plots/training.png')

    plt.show()

# %% [markdown]
# # Load data

# %%
seis= np.load('../data_decatur/processed/seismic-ccs1-vw1-inline.npy')
phi_true = np.load('../data_decatur/processed/porosity-ccs1-vw1-inline.npy')

# %% [markdown]
# # Shape and Statistics

# %%
phi_true.mean()
# Out:
# 0.09534691464450182

# %%
phi_true.min()
# Out:
# 1.0961666703224182e-05

# %%
phi_true.max()
# Out:
# 0.24446946382522583

# %%
seis.shape
# Out:
# (1211, 124)

# %%
phi_true.shape
# Out:
# (1211, 124)

# %%
type(phi_true)
# Out:
# numpy.ndarray

# %%
phi_true[0]
# Out:
# array([2.31085606e-02, 6.95891976e-02, 7.55213499e-02, 8.58892798e-02,
#        1.02129519e-01, 1.00000000e-04, 2.27591097e-02, 9.58393812e-02,
#        8.11687112e-02, 5.09966500e-02, 5.34149408e-02, 6.63141012e-02,
#        7.19876289e-02, 7.15309381e-02, 7.37545490e-02, 7.74723887e-02,
#        7.93744326e-02, 8.12547803e-02, 7.68014193e-02, 7.54390359e-02,
#        8.09006691e-02, 8.75442028e-02, 9.38097835e-02, 9.92434621e-02,
#        9.13296938e-02, 8.76421332e-02, 8.62396955e-02, 8.90834332e-02,
#        9.44752693e-02, 9.79376435e-02, 9.67548490e-02, 1.00848556e-01,
#        1.05480313e-01, 9.96413827e-02, 9.48247313e-02, 9.52327847e-02,
#        9.67547894e-02, 9.63712335e-02, 9.61178541e-02, 1.02648258e-01,
#        1.02585375e-01, 9.46376920e-02, 9.16643143e-02, 8.92438889e-02,
#        8.59658122e-02, 8.27050209e-02, 8.00532103e-02, 7.66461492e-02,
#        7.71986246e-02, 8.22175145e-02, 8.22345614e-02, 8.24415088e-02,
#        7.68221617e-02, 9.04704332e-02, 8.44264030e-02, 8.54933858e-02,
#        8.55472088e-02, 7.99808502e-02, 7.67523646e-02, 7.82725811e-02,
#        8.83457661e-02, 1.15381181e-01, 1.28328979e-01, 1.22690618e-01,
#        1.27937019e-01, 1.41524315e-01, 1.47487283e-01, 1.64139926e-01,
#        1.74969971e-01, 1.93967640e-01, 2.06459582e-01, 1.90667629e-01,
#        1.80683792e-01, 1.71066344e-01, 1.60530269e-01, 1.85334206e-01,
#        2.04356492e-01, 2.08036721e-01, 1.71609521e-01, 1.45551205e-01,
#        1.20353878e-01, 1.43933356e-01, 1.67661190e-01, 1.66025996e-01,
#        1.66714370e-01, 1.64897382e-01, 1.68573380e-01, 1.70230031e-01,
#        1.79347634e-01, 1.83068931e-01, 2.10522652e-01, 1.31585181e-01,
#        8.16836357e-02, 7.94885159e-02, 7.61017799e-02, 6.76918030e-02,
#        6.21442571e-02, 6.58532977e-02, 7.53659606e-02, 6.24042265e-02,
#        3.52985337e-02, 3.94251160e-02, 6.49503469e-02, 7.38595128e-02,
#        6.46105409e-02, 5.79565354e-02, 5.96019961e-02, 6.02579899e-02,
#        6.10844493e-02, 6.36631250e-02, 6.06986172e-02, 5.15605658e-02,
#        5.47976233e-02, 6.87755346e-02, 6.54115081e-02, 2.67695375e-02,
#        1.88801549e-02, 2.06224471e-02, 1.97673067e-02, 2.01897882e-02,
#        2.21631117e-02, 2.41503380e-02, 2.10421570e-02, 2.59842612e-02])

# %%
plt.hist(phi_true[0], bins=20)
# Out:
# (array([ 1.,  5.,  6.,  2.,  2.,  9., 11., 25., 17., 14.,  2.,  2.,  3.,
#          3.,  1.,  6.,  5.,  4.,  2.,  4.]),
#  array([1.00000000e-04, 1.06211326e-02, 2.11422652e-02, 3.16633978e-02,
#         4.21845303e-02, 5.27056629e-02, 6.32267955e-02, 7.37479281e-02,
#         8.42690607e-02, 9.47901933e-02, 1.05311326e-01, 1.15832458e-01,
#         1.26353591e-01, 1.36874724e-01, 1.47395856e-01, 1.57916989e-01,
#         1.68438121e-01, 1.78959254e-01, 1.89480387e-01, 2.00001519e-01,
#         2.10522652e-01]),
#  <BarContainer object of 20 artists>)

# %%
def min_max_scale(x, min, max):

  x_std = (x - min) / (max - min)
  x_scaled = x_std * 2 - 1
  return x_scaled

def inverse_min_max_scale(x, min, max):

  x_normalized = (x + 1) / 2
  x_unscaled = x_normalized * (max - min) + min
  return x_unscaled

# %%
phi_max=np.max(phi_true) #can also take 1 or critical porosity (0.4)
phi_min=np.min(phi_true) #can also take 0

# %%
phi_scaled = min_max_scale(phi_true, min= phi_min, max=phi_max)
phi_unscaled = inverse_min_max_scale(phi_scaled, min= phi_min, max=phi_max)

# %%
plt.hist(phi_scaled[0], bins=20)
# Out:
# (array([ 1.,  5.,  6.,  2.,  2.,  9., 11., 25., 17., 14.,  2.,  2.,  3.,
#          3.,  1.,  6.,  5.,  4.,  2.,  4.]),
#  array([-0.99927155, -0.9131945 , -0.82711746, -0.74104042, -0.65496337,
#         -0.56888633, -0.48280928, -0.39673224, -0.3106552 , -0.22457815,
#         -0.13850111, -0.05242407,  0.03365298,  0.11973002,  0.20580707,
#          0.29188411,  0.37796115,  0.4640382 ,  0.55011524,  0.63619228,
#          0.72226933]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(phi_unscaled[0], bins=20)
# Out:
# (array([ 1.,  5.,  6.,  2.,  2.,  9., 11., 25., 17., 14.,  2.,  2.,  3.,
#          3.,  1.,  6.,  5.,  4.,  2.,  4.]),
#  array([1.00000000e-04, 1.06211326e-02, 2.11422652e-02, 3.16633978e-02,
#         4.21845303e-02, 5.27056629e-02, 6.32267955e-02, 7.37479281e-02,
#         8.42690607e-02, 9.47901933e-02, 1.05311326e-01, 1.15832458e-01,
#         1.26353591e-01, 1.36874724e-01, 1.47395856e-01, 1.57916989e-01,
#         1.68438121e-01, 1.78959254e-01, 1.89480387e-01, 2.00001519e-01,
#         2.10522652e-01]),
#  <BarContainer object of 20 artists>)

# %%
# Normalizing the input and output data  

seis_normalized = (seis - np.min(seis))/(np.max(seis)-np.min(seis))


true_output=np.zeros((seis_normalized.shape[0],seis_normalized.shape[1]))
true_output[:,0:199]=(phi_true-phi_min)/(phi_max-phi_min)

# %%
true_output.shape
# Out:
# (1211, 124)

# %%
np.min(seis), np.max(seis)
# Out:
# (-16131.97265625, 17048.5546875)

# %%
np.min(true_output), np.max(true_output)
# Out:
# (0.0, 1.0)

# %%
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(seis,phi_scaled, test_size=0.20, random_state=1)

X_test,X_val,Y_test,Y_val = model_selection.train_test_split(seis,phi_scaled, test_size=0.5, random_state=1)

"""Esta noramlización de los datos se hace para que los datos puedan entrar al modelo Conv1D. 
TensotFlow recibe un tensor de 3 Dimensiones de la forma (samples, timesteps, features).
Por lo cual es necesario agregar una tercera dimensión"""
X_train_final = np.expand_dims(X_train, axis=1)
X_test_final = np.expand_dims(X_test, axis=1)
X_val_final = np.expand_dims(X_val, axis=1)

# %%
print(f'Shape train: {X_train_final.shape}')
print(f'Shape test: {X_test_final.shape}')
print(f'Shape val: {X_val_final.shape}')
# Out:
# Shape train: (968, 1, 124)
# Shape test: (605, 1, 124)
# Shape val: (606, 1, 124)

# %% [markdown]
# # Arquitectura Red Neuronal

# %%
given_seed=2
def get_model():
    """El input shape de tal forma sería entonces (1, 246) ya que son trazas sismicas, 2000 de ellas"""
    model = tf.keras.models.Sequential(
        #probar a poner capa densa al comienzo y luego pasar por la convolución
    [tf.keras.layers.Dense(units=124), #reducir capas flatten
    BatchNormalization(),
    Activation('tanh'),        
        
    Conv1D(filters=512, kernel_size=3,
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros', padding='same'),
    BatchNormalization(),
    Activation('tanh'),
    
    Conv1D(filters=512, kernel_size=3, padding='same', 
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros',),
    BatchNormalization(),
    Activation('tanh'),
    
    Conv1D(filters=512, kernel_size=3, padding='same', 
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros',),
    BatchNormalization(),
    Activation('tanh'),
    
    Conv1D(filters=512, kernel_size=3, padding='same', 
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros',),
    BatchNormalization(),
    Activation('tanh'),
    
    Conv1D(filters=512, kernel_size=3, padding='same', 
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros',),
    BatchNormalization(),
    Activation('tanh'),
    Conv1D(filters=512, kernel_size=3, padding='same', 
                            kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros',),
    BatchNormalization(),
    Activation('tanh'),

    #tratar de cambiar el padding same 
    #batch normalization, da estabilidad. Para ponerlo despues de la ultima conv, luego el batch y luego la activación
    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(units=200), #reducir capas flatten
    BatchNormalization(),
    Activation('tanh'),
    
    tf.keras.layers.Dense(units=124), #probar softmax, sigmoid, leakyrelu, linear
    Activation('tanh')
])
    return model

def naive_model():
    """El input shape de tal forma sería entonces (1, 246) ya que son trazas sismicas, 2000 de ellas"""

    model = tf.keras.models.Sequential()
        #probar a poner capa densa al comienzo y luego pasar por la convolución
    input_final = tf.keras.Input(shape=(X_train_final.shape[1:]))
    
    model.add(input_final)
    
    model.add(Conv1D(filters=128, kernel_size=3, strides=1, padding='same',kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')) 
    model.add(Activation('tanh'))
    
    model.add(Conv1D(filters=256, kernel_size=3, strides=1, padding='same',kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')) 
    model.add(Activation('tanh'))
    
    model.add(Conv1D(filters=512, kernel_size=3, strides=1, padding='same',kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')) 
    model.add(Activation('tanh'))
    
    model.add(Conv1D(filters=1024, kernel_size=3, strides=1, padding='same',kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros')) 
    model.add(Activation('tanh'))
    model.add(tf.keras.layers.Dropout(rate=0.3))
    

    model.add(tf.keras.layers.Flatten())
 
    
    model.add(tf.keras.layers.Dense(units=124,kernel_initializer=initializers.he_uniform(seed=given_seed), bias_initializer='zeros'))
    model.add(Activation('tanh'))

    return model
    

model_phi = naive_model()
model_phi.build((2500,1,124))
model_phi.summary()
# Out:
# 2024-05-18 11:18:34.406131: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.628795: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.628867: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.631581: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.631705: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.631752: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.842035: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.842140: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.842150: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-05-18 11:18:34.842203: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-05-18 11:18:34.842221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2865 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 128)            47744
#
#  activation (Activation)     (None, 1, 128)            0
#
#  conv1d_1 (Conv1D)           (None, 1, 256)            98560
#
#  activation_1 (Activation)   (None, 1, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 1, 512)            393728
#
#  activation_2 (Activation)   (None, 1, 512)            0
#
#  conv1d_3 (Conv1D)           (None, 1, 1024)           1573888
#
#  activation_3 (Activation)   (None, 1, 1024)           0
#
#  dropout (Dropout)           (None, 1, 1024)           0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 124)               127100
#
#  activation_4 (Activation)   (None, 124)               0
#
# =================================================================
# Total params: 2241020 (8.55 MB)
# Trainable params: 2241020 (8.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model_phi, show_shapes=True, dpi=72, to_file='model.png')

# %%
optimizer = tf.keras.optimizers.Adam()

model_phi.compile(optimizer=optimizer,
                    loss='mse',
                    metrics=['accuracy'])

# %%
#callback_early = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, mode='auto')
checkpoint = tf.keras.callbacks.ModelCheckpoint('model_naive.h5', monitor='val_accuracy', mode='max', verbose=1, save_weights_only=True)
callback_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', factor=0.5, patience=30, min_lr=0.000001)

# %% [markdown]
# # Entrenamiento

# %%
history_early = model_phi.fit(x=X_train_final, 
                                y=Y_train,
                                epochs=epocas,
                                batch_size=40,
                                callbacks=[checkpoint, callback_lr],
                                validation_data=(X_val_final, Y_val)                          
                                )
# Out:
# Epoch 1/500
# 2024-05-18 11:18:36.692577: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-05-18 11:18:37.042874: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-18 11:18:37.907592: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-05-18 11:18:38.881441: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f2a840b1db0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-18 11:18:38.881496: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1050, Compute Capability 6.1
# 2024-05-18 11:18:38.904717: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716049119.081690    4527 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.2221
# Epoch 1: saving model to model_naive.h5
# 25/25 [==============================] - 7s 67ms/step - loss: 0.0908 - accuracy: 0.2221 - val_loss: 0.0229 - val_accuracy: 0.3548 - lr: 0.0010
# Epoch 2/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.3140
# Epoch 2: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0338 - accuracy: 0.3140 - val_loss: 0.0118 - val_accuracy: 0.4703 - lr: 0.0010
# Epoch 3/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0219 - accuracy: 0.3631
# Epoch 3: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0214 - accuracy: 0.3750 - val_loss: 0.0072 - val_accuracy: 0.5479 - lr: 0.0010
# Epoch 4/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0159 - accuracy: 0.4000
# Epoch 4: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0159 - accuracy: 0.4050 - val_loss: 0.0053 - val_accuracy: 0.5413 - lr: 0.0010
# Epoch 5/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0137 - accuracy: 0.4750
# Epoch 5: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0136 - accuracy: 0.4742 - val_loss: 0.0051 - val_accuracy: 0.5743 - lr: 0.0010
# Epoch 6/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0116 - accuracy: 0.4315
# Epoch 6: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0115 - accuracy: 0.4370 - val_loss: 0.0040 - val_accuracy: 0.5693 - lr: 0.0010
# Epoch 7/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0095 - accuracy: 0.4655
# Epoch 7: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0095 - accuracy: 0.4731 - val_loss: 0.0037 - val_accuracy: 0.6139 - lr: 0.0010
# Epoch 8/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0086 - accuracy: 0.5405
# Epoch 8: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0086 - accuracy: 0.5300 - val_loss: 0.0035 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 9/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.5320
# Epoch 9: saving model to model_naive.h5
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0085 - accuracy: 0.5320 - val_loss: 0.0038 - val_accuracy: 0.5743 - lr: 0.0010
# Epoch 10/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0077 - accuracy: 0.5250
# Epoch 10: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0076 - accuracy: 0.5289 - val_loss: 0.0029 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 11/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0069 - accuracy: 0.5357
# Epoch 11: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0068 - accuracy: 0.5403 - val_loss: 0.0028 - val_accuracy: 0.6551 - lr: 0.0010
# Epoch 12/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0061 - accuracy: 0.5702
# Epoch 12: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0061 - accuracy: 0.5723 - val_loss: 0.0028 - val_accuracy: 0.6650 - lr: 0.0010
# Epoch 13/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0061 - accuracy: 0.5370
# Epoch 13: saving model to model_naive.h5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - accuracy: 0.5351 - val_loss: 0.0027 - val_accuracy: 0.6551 - lr: 0.0010
# Epoch 14/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0059 - accuracy: 0.5859
# Epoch 14: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0058 - accuracy: 0.5785 - val_loss: 0.0033 - val_accuracy: 0.6403 - lr: 0.0010
# Epoch 15/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0057 - accuracy: 0.5786
# Epoch 15: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0057 - accuracy: 0.5785 - val_loss: 0.0023 - val_accuracy: 0.7162 - lr: 0.0010
# Epoch 16/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0052 - accuracy: 0.6024
# Epoch 16: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0051 - accuracy: 0.6074 - val_loss: 0.0024 - val_accuracy: 0.6980 - lr: 0.0010
# Epoch 17/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0053 - accuracy: 0.5979
# Epoch 17: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 0.5981 - val_loss: 0.0026 - val_accuracy: 0.6898 - lr: 0.0010
# Epoch 18/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.6240
# Epoch 18: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0047 - accuracy: 0.6240 - val_loss: 0.0018 - val_accuracy: 0.6848 - lr: 0.0010
# Epoch 19/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0045 - accuracy: 0.5893
# Epoch 19: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0045 - accuracy: 0.5919 - val_loss: 0.0019 - val_accuracy: 0.6320 - lr: 0.0010
# Epoch 20/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 0.5813
# Epoch 20: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0046 - accuracy: 0.5816 - val_loss: 0.0024 - val_accuracy: 0.6832 - lr: 0.0010
# Epoch 21/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.6426
# Epoch 21: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0045 - accuracy: 0.6426 - val_loss: 0.0020 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 22/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0043 - accuracy: 0.6179
# Epoch 22: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 0.6116 - val_loss: 0.0020 - val_accuracy: 0.7096 - lr: 0.0010
# Epoch 23/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0041 - accuracy: 0.6179
# Epoch 23: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0041 - accuracy: 0.6147 - val_loss: 0.0023 - val_accuracy: 0.6733 - lr: 0.0010
# Epoch 24/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0045 - accuracy: 0.6438
# Epoch 24: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0045 - accuracy: 0.6405 - val_loss: 0.0020 - val_accuracy: 0.7343 - lr: 0.0010
# Epoch 25/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.6426
# Epoch 25: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 0.6426 - val_loss: 0.0023 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 26/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.6136
# Epoch 26: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0040 - accuracy: 0.6136 - val_loss: 0.0018 - val_accuracy: 0.6931 - lr: 0.0010
# Epoch 27/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.6477
# Epoch 27: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0037 - accuracy: 0.6477 - val_loss: 0.0028 - val_accuracy: 0.6287 - lr: 0.0010
# Epoch 28/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.6271
# Epoch 28: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0041 - accuracy: 0.6271 - val_loss: 0.0022 - val_accuracy: 0.7013 - lr: 0.0010
# Epoch 29/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.6353
# Epoch 29: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 0.6353 - val_loss: 0.0021 - val_accuracy: 0.7690 - lr: 0.0010
# Epoch 30/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0039 - accuracy: 0.6571
# Epoch 30: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 0.6560 - val_loss: 0.0019 - val_accuracy: 0.7030 - lr: 0.0010
# Epoch 31/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0036 - accuracy: 0.6476
# Epoch 31: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 0.6467 - val_loss: 0.0019 - val_accuracy: 0.6683 - lr: 0.0010
# Epoch 32/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0035 - accuracy: 0.6615
# Epoch 32: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 0.6612 - val_loss: 0.0019 - val_accuracy: 0.7228 - lr: 0.0010
# Epoch 33/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.6643
# Epoch 33: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0033 - accuracy: 0.6643 - val_loss: 0.0016 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 34/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0032 - accuracy: 0.6619
# Epoch 34: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0032 - accuracy: 0.6570 - val_loss: 0.0016 - val_accuracy: 0.7277 - lr: 0.0010
# Epoch 35/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0032 - accuracy: 0.6571
# Epoch 35: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0032 - accuracy: 0.6550 - val_loss: 0.0021 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 36/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.6446
# Epoch 36: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0036 - accuracy: 0.6446 - val_loss: 0.0022 - val_accuracy: 0.6931 - lr: 0.0010
# Epoch 37/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0033 - accuracy: 0.6641
# Epoch 37: saving model to model_naive.h5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0033 - accuracy: 0.6694 - val_loss: 0.0016 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 38/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0031 - accuracy: 0.6524
# Epoch 38: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 0.6477 - val_loss: 0.0017 - val_accuracy: 0.6898 - lr: 0.0010
# Epoch 39/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.6632
# Epoch 39: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0033 - accuracy: 0.6632 - val_loss: 0.0020 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 40/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0035 - accuracy: 0.6571
# Epoch 40: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0035 - accuracy: 0.6519 - val_loss: 0.0019 - val_accuracy: 0.6601 - lr: 0.0010
# Epoch 41/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.6529
# Epoch 41: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0032 - accuracy: 0.6529 - val_loss: 0.0018 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 42/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0032 - accuracy: 0.6886
# Epoch 42: saving model to model_naive.h5
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 0.6787 - val_loss: 0.0019 - val_accuracy: 0.7327 - lr: 0.0010
# Epoch 43/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.6477
# Epoch 43: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0032 - accuracy: 0.6477 - val_loss: 0.0019 - val_accuracy: 0.7079 - lr: 0.0010
# Epoch 44/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0034 - accuracy: 0.6595
# Epoch 44: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0034 - accuracy: 0.6581 - val_loss: 0.0020 - val_accuracy: 0.6403 - lr: 0.0010
# Epoch 45/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.6622
# Epoch 45: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0031 - accuracy: 0.6622 - val_loss: 0.0016 - val_accuracy: 0.6931 - lr: 0.0010
# Epoch 46/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0030 - accuracy: 0.6595
# Epoch 46: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0029 - accuracy: 0.6601 - val_loss: 0.0016 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 47/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0029 - accuracy: 0.6663
# Epoch 47: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 0.6684 - val_loss: 0.0014 - val_accuracy: 0.7409 - lr: 0.0010
# Epoch 48/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.6901
# Epoch 48: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.6901 - val_loss: 0.0016 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 49/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.6839
# Epoch 49: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.6839 - val_loss: 0.0015 - val_accuracy: 0.6700 - lr: 0.0010
# Epoch 50/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0028 - accuracy: 0.6714
# Epoch 50: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0028 - accuracy: 0.6746 - val_loss: 0.0014 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 51/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0026 - accuracy: 0.6500
# Epoch 51: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 0.6560 - val_loss: 0.0016 - val_accuracy: 0.7294 - lr: 0.0010
# Epoch 52/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.6663
# Epoch 52: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 0.6663 - val_loss: 0.0015 - val_accuracy: 0.7294 - lr: 0.0010
# Epoch 53/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.6632
# Epoch 53: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0028 - accuracy: 0.6632 - val_loss: 0.0017 - val_accuracy: 0.7195 - lr: 0.0010
# Epoch 54/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0026 - accuracy: 0.6726
# Epoch 54: saving model to model_naive.h5
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 0.6715 - val_loss: 0.0018 - val_accuracy: 0.7327 - lr: 0.0010
# Epoch 55/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.6901
# Epoch 55: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0029 - accuracy: 0.6901 - val_loss: 0.0015 - val_accuracy: 0.7492 - lr: 0.0010
# Epoch 56/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0028 - accuracy: 0.7012
# Epoch 56: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.6921 - val_loss: 0.0021 - val_accuracy: 0.6832 - lr: 0.0010
# Epoch 57/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 0.6781
# Epoch 57: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 0.6787 - val_loss: 0.0018 - val_accuracy: 0.7228 - lr: 0.0010
# Epoch 58/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0027 - accuracy: 0.6571
# Epoch 58: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0027 - accuracy: 0.6632 - val_loss: 0.0020 - val_accuracy: 0.7343 - lr: 0.0010
# Epoch 59/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.6715
# Epoch 59: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 0.6715 - val_loss: 0.0013 - val_accuracy: 0.7244 - lr: 0.0010
# Epoch 60/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.6896
# Epoch 60: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0024 - accuracy: 0.6860 - val_loss: 0.0017 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 61/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.6760
# Epoch 61: saving model to model_naive.h5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0025 - accuracy: 0.6777 - val_loss: 0.0014 - val_accuracy: 0.7475 - lr: 0.0010
# Epoch 62/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0025 - accuracy: 0.6783
# Epoch 62: saving model to model_naive.h5
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0025 - accuracy: 0.6808 - val_loss: 0.0016 - val_accuracy: 0.7541 - lr: 0.0010
# Epoch 63/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.7031
# Epoch 63: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 0.7035 - val_loss: 0.0014 - val_accuracy: 0.6964 - lr: 0.0010
# Epoch 64/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0024 - accuracy: 0.6893
# Epoch 64: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 0.6849 - val_loss: 0.0012 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 65/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.6932
# Epoch 65: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 0.6932 - val_loss: 0.0013 - val_accuracy: 0.7046 - lr: 0.0010
# Epoch 66/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0023 - accuracy: 0.7024
# Epoch 66: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0023 - accuracy: 0.7004 - val_loss: 0.0014 - val_accuracy: 0.7211 - lr: 0.0010
# Epoch 67/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.6890
# Epoch 67: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.6890 - val_loss: 0.0014 - val_accuracy: 0.7178 - lr: 0.0010
# Epoch 68/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0022 - accuracy: 0.7104
# Epoch 68: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.7118 - val_loss: 0.0014 - val_accuracy: 0.6782 - lr: 0.0010
# Epoch 69/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0022 - accuracy: 0.6989
# Epoch 69: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 0.6880 - val_loss: 0.0014 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 70/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0022 - accuracy: 0.7240
# Epoch 70: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.7231 - val_loss: 0.0014 - val_accuracy: 0.6832 - lr: 0.0010
# Epoch 71/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0022 - accuracy: 0.7000
# Epoch 71: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.7076 - val_loss: 0.0013 - val_accuracy: 0.7690 - lr: 0.0010
# Epoch 72/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0022 - accuracy: 0.7207
# Epoch 72: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0021 - accuracy: 0.7149 - val_loss: 0.0015 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 73/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0022 - accuracy: 0.7024
# Epoch 73: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.7097 - val_loss: 0.0013 - val_accuracy: 0.7739 - lr: 0.0010
# Epoch 74/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.7045
# Epoch 74: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.7045 - val_loss: 0.0020 - val_accuracy: 0.7541 - lr: 0.0010
# Epoch 75/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.6792
# Epoch 75: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0025 - accuracy: 0.6787 - val_loss: 0.0017 - val_accuracy: 0.7739 - lr: 0.0010
# Epoch 76/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0023 - accuracy: 0.6917
# Epoch 76: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.6983 - val_loss: 0.0013 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 77/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0021 - accuracy: 0.6802
# Epoch 77: saving model to model_naive.h5
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 0.6818 - val_loss: 0.0012 - val_accuracy: 0.7805 - lr: 0.0010
# Epoch 78/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0020 - accuracy: 0.7239
# Epoch 78: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 0.7211 - val_loss: 0.0012 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 79/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0021 - accuracy: 0.7148
# Epoch 79: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0021 - accuracy: 0.7107 - val_loss: 0.0015 - val_accuracy: 0.6980 - lr: 0.0010
# Epoch 80/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0020 - accuracy: 0.6967
# Epoch 80: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0020 - accuracy: 0.6973 - val_loss: 0.0013 - val_accuracy: 0.7475 - lr: 0.0010
# Epoch 81/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0022 - accuracy: 0.7148
# Epoch 81: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 0.7190 - val_loss: 0.0018 - val_accuracy: 0.7261 - lr: 0.0010
# Epoch 82/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0022 - accuracy: 0.7369
# Epoch 82: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.7376 - val_loss: 0.0013 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 83/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.6756
# Epoch 83: saving model to model_naive.h5
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0020 - accuracy: 0.6756 - val_loss: 0.0012 - val_accuracy: 0.7855 - lr: 0.0010
# Epoch 84/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0019 - accuracy: 0.7011
# Epoch 84: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 0.7014 - val_loss: 0.0013 - val_accuracy: 0.7673 - lr: 0.0010
# Epoch 85/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.7283
# Epoch 85: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.7283 - val_loss: 0.0012 - val_accuracy: 0.7459 - lr: 0.0010
# Epoch 86/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.7211
# Epoch 86: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7211 - val_loss: 0.0011 - val_accuracy: 0.7492 - lr: 0.0010
# Epoch 87/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0018 - accuracy: 0.7010
# Epoch 87: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 0.7004 - val_loss: 0.0014 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 88/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0020 - accuracy: 0.7043
# Epoch 88: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0020 - accuracy: 0.7045 - val_loss: 0.0014 - val_accuracy: 0.7723 - lr: 0.0010
# Epoch 89/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.6911
# Epoch 89: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.6911 - val_loss: 0.0012 - val_accuracy: 0.7706 - lr: 0.0010
# Epoch 90/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.7128
# Epoch 90: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 0.7128 - val_loss: 0.0013 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 91/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0021 - accuracy: 0.7071
# Epoch 91: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.7004 - val_loss: 0.0012 - val_accuracy: 0.7393 - lr: 0.0010
# Epoch 92/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 0.7021
# Epoch 92: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 0.7025 - val_loss: 0.0011 - val_accuracy: 0.7327 - lr: 0.0010
# Epoch 93/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0018 - accuracy: 0.7146
# Epoch 93: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 0.7138 - val_loss: 0.0013 - val_accuracy: 0.7492 - lr: 0.0010
# Epoch 94/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.7200
# Epoch 94: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 0.7200 - val_loss: 0.0013 - val_accuracy: 0.7492 - lr: 0.0010
# Epoch 95/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0020 - accuracy: 0.7143
# Epoch 95: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 0.7004 - val_loss: 0.0014 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 96/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.7004
# Epoch 96: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.7004 - val_loss: 0.0013 - val_accuracy: 0.7475 - lr: 0.0010
# Epoch 97/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0019 - accuracy: 0.7143
# Epoch 97: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 0.7128 - val_loss: 0.0013 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 98/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0018 - accuracy: 0.7188
# Epoch 98: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7190 - val_loss: 0.0014 - val_accuracy: 0.7343 - lr: 0.0010
# Epoch 99/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7583
# Epoch 99: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7438 - val_loss: 0.0011 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 100/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7143
# Epoch 100: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0018 - accuracy: 0.7221 - val_loss: 0.0012 - val_accuracy: 0.7822 - lr: 0.0010
# Epoch 101/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.6976
# Epoch 101: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.6921 - val_loss: 0.0012 - val_accuracy: 0.7178 - lr: 0.0010
# Epoch 102/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7405
# Epoch 102: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7324 - val_loss: 0.0010 - val_accuracy: 0.7294 - lr: 0.0010
# Epoch 103/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7179
# Epoch 103: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.7169 - val_loss: 0.0011 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 104/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 0.7152
# Epoch 104: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 0.7118 - val_loss: 0.0011 - val_accuracy: 0.7756 - lr: 0.0010
# Epoch 105/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7262
# Epoch 105: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.7293 - val_loss: 0.0011 - val_accuracy: 0.7690 - lr: 0.0010
# Epoch 106/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7250
# Epoch 106: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7304 - val_loss: 0.0014 - val_accuracy: 0.7789 - lr: 0.0010
# Epoch 107/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.7314
# Epoch 107: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7314 - val_loss: 0.0012 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 108/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7274
# Epoch 108: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.7231 - val_loss: 9.9188e-04 - val_accuracy: 0.7030 - lr: 0.0010
# Epoch 109/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7170
# Epoch 109: saving model to model_naive.h5
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 0.7190 - val_loss: 0.0011 - val_accuracy: 0.7558 - lr: 0.0010
# Epoch 110/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7274
# Epoch 110: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.7169 - val_loss: 0.0010 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 111/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7381
# Epoch 111: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7314 - val_loss: 0.0011 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 112/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.6893
# Epoch 112: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.6911 - val_loss: 0.0010 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 113/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.6990
# Epoch 113: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 0.7004 - val_loss: 0.0011 - val_accuracy: 0.7459 - lr: 0.0010
# Epoch 114/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7262
# Epoch 114: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.7335 - val_loss: 0.0011 - val_accuracy: 0.7162 - lr: 0.0010
# Epoch 115/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.7104
# Epoch 115: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 0.7107 - val_loss: 0.0011 - val_accuracy: 0.7624 - lr: 0.0010
# Epoch 116/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7060
# Epoch 116: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.7149 - val_loss: 0.0011 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 117/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7333
# Epoch 117: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.7314 - val_loss: 0.0012 - val_accuracy: 0.7624 - lr: 0.0010
# Epoch 118/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7167
# Epoch 118: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.7066 - val_loss: 0.0010 - val_accuracy: 0.7954 - lr: 0.0010
# Epoch 119/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7119
# Epoch 119: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.7190 - val_loss: 0.0011 - val_accuracy: 0.7673 - lr: 0.0010
# Epoch 120/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7119
# Epoch 120: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.7200 - val_loss: 0.0011 - val_accuracy: 0.7690 - lr: 0.0010
# Epoch 121/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7524
# Epoch 121: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0017 - accuracy: 0.7510 - val_loss: 0.0011 - val_accuracy: 0.7459 - lr: 0.0010
# Epoch 122/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 0.7326
# Epoch 122: saving model to model_naive.h5
# 25/25 [==============================] - 1s 25ms/step - loss: 0.0016 - accuracy: 0.7324 - val_loss: 0.0011 - val_accuracy: 0.7426 - lr: 0.0010
# Epoch 123/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 0.7315
# Epoch 123: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 0.7283 - val_loss: 0.0010 - val_accuracy: 0.8416 - lr: 0.0010
# Epoch 124/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7310
# Epoch 124: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.7345 - val_loss: 9.6349e-04 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 125/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7293
# Epoch 125: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.7293 - val_loss: 9.4484e-04 - val_accuracy: 0.7970 - lr: 0.0010
# Epoch 126/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7293
# Epoch 126: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.7293 - val_loss: 0.0011 - val_accuracy: 0.7673 - lr: 0.0010
# Epoch 127/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7167
# Epoch 127: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.7283 - val_loss: 0.0011 - val_accuracy: 0.7475 - lr: 0.0010
# Epoch 128/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7452
# Epoch 128: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 0.7479 - val_loss: 0.0012 - val_accuracy: 0.7888 - lr: 0.0010
# Epoch 129/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 0.7500
# Epoch 129: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.7500 - val_loss: 0.0012 - val_accuracy: 0.7904 - lr: 0.0010
# Epoch 130/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0017 - accuracy: 0.7214
# Epoch 130: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 0.7200 - val_loss: 9.7209e-04 - val_accuracy: 0.7723 - lr: 0.0010
# Epoch 131/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7386
# Epoch 131: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 0.7345 - val_loss: 0.0011 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 132/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0016 - accuracy: 0.7216
# Epoch 132: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 0.7231 - val_loss: 9.9232e-04 - val_accuracy: 0.7376 - lr: 0.0010
# Epoch 133/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7179
# Epoch 133: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 0.7221 - val_loss: 0.0011 - val_accuracy: 0.7772 - lr: 0.0010
# Epoch 134/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.7366
# Epoch 134: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.7366 - val_loss: 0.0011 - val_accuracy: 0.7591 - lr: 0.0010
# Epoch 135/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7000
# Epoch 135: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.6973 - val_loss: 0.0010 - val_accuracy: 0.7327 - lr: 0.0010
# Epoch 136/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7252
# Epoch 136: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.7252 - val_loss: 9.9649e-04 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 137/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7238
# Epoch 137: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 0.7221 - val_loss: 0.0011 - val_accuracy: 0.7871 - lr: 0.0010
# Epoch 138/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.6973
# Epoch 138: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.6973 - val_loss: 0.0010 - val_accuracy: 0.7921 - lr: 0.0010
# Epoch 139/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7366
# Epoch 139: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.7366 - val_loss: 9.6260e-04 - val_accuracy: 0.7409 - lr: 0.0010
# Epoch 140/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 0.7302
# Epoch 140: saving model to model_naive.h5
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 0.7304 - val_loss: 9.7291e-04 - val_accuracy: 0.7574 - lr: 0.0010
# Epoch 141/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 0.7260
# Epoch 141: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 0.7221 - val_loss: 0.0011 - val_accuracy: 0.7393 - lr: 0.0010
# Epoch 142/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7060
# Epoch 142: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.7056 - val_loss: 0.0011 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 143/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7107
# Epoch 143: saving model to model_naive.h5
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0015 - accuracy: 0.7107 - val_loss: 9.4531e-04 - val_accuracy: 0.7508 - lr: 0.0010
# Epoch 144/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.7273
# Epoch 144: saving model to model_naive.h5
# 25/25 [==============================] - 1s 29ms/step - loss: 0.0014 - accuracy: 0.7273 - val_loss: 8.5863e-04 - val_accuracy: 0.7756 - lr: 0.0010
# Epoch 145/500
# 24/25 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 0.7302
# Epoch 145: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 0.7314 - val_loss: 0.0010 - val_accuracy: 0.7987 - lr: 0.0010
# Epoch 146/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7310
# Epoch 146: saving model to model_naive.h5
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.7366 - val_loss: 9.3002e-04 - val_accuracy: 0.7607 - lr: 0.0010
# Epoch 147/500
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0014 - accuracy: 0.7205
# Epoch 147: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 0.7252 - val_loss: 0.0010 - val_accuracy: 0.7756 - lr: 0.0010
# Epoch 148/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.7128
# Epoch 148: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 0.7128 - val_loss: 0.0012 - val_accuracy: 0.8102 - lr: 0.0010
# Epoch 149/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7179
# Epoch 149: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 0.7221 - val_loss: 0.0011 - val_accuracy: 0.7459 - lr: 0.0010
# Epoch 150/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 0.7310
# Epoch 150: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 0.7273 - val_loss: 9.5554e-04 - val_accuracy: 0.7739 - lr: 0.0010
# Epoch 151/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0014 - accuracy: 0.7119
# Epoch 151: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 0.7045 - val_loss: 9.6711e-04 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 152/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.7366
# Epoch 152: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 0.7366 - val_loss: 6.6472e-04 - val_accuracy: 0.7739 - lr: 5.0000e-04
# Epoch 153/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0011 - accuracy: 0.7881
# Epoch 153: saving model to model_naive.h5
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0010 - accuracy: 0.7758 - val_loss: 6.0748e-04 - val_accuracy: 0.7640 - lr: 5.0000e-04
# Epoch 154/500
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0010 - accuracy: 0.7370
# Epoch 154: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.0010 - accuracy: 0.7366 - val_loss: 6.2482e-04 - val_accuracy: 0.7772 - lr: 5.0000e-04
# Epoch 155/500
# 25/25 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.7479
# Epoch 155: saving model to model_naive.h5
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0010 - accuracy: 0.7479 - val_loss: 6.2302e-04 - val_accuracy: 0.7855 - lr: 5.0000e-04
# Epoch 156/500
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0010 - accuracy: 0.7583
# Epoch 156: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 0.
# 23/25 [==========================>...] - ETA: 0s - loss: 5.8735e-04 - accuracy: 0.7967
# Epoch 485: saving model to model_naive.h5
# 25/25 [==============================] - 1s 22ms/step - loss: 5.8967e-04 - accuracy: 0.8006 - val_loss: 3.4116e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 486/500
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8820e-04 - accuracy: 0.8010
# Epoch 486: saving model to model_naive.h5
# 25/25 [==============================] - 1s 21ms/step - loss: 5.8735e-04 - accuracy: 0.8027 - val_loss: 3.4103e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 487/500
# 22/25 [=========================>....] - ETA: 0s - loss: 5.9324e-04 - accuracy: 0.7966
# Epoch 487: saving model to model_naive.h5
# 25/25 [==============================] - 1s 20ms/step - loss: 5.8998e-04 - accuracy: 0.7955 - val_loss: 3.4102e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 488/500
# 25/25 [==============================] - ETA: 0s - loss: 5.9224e-04 - accuracy: 0.8058
# Epoch 488: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.9224e-04 - accuracy: 0.8058 - val_loss: 3.4109e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 489/500
# 23/25 [==========================>...] - ETA: 0s - loss: 5.8989e-04 - accuracy: 0.7946
# Epoch 489: saving model to model_naive.h5
# 25/25 [==============================] - 1s 21ms/step - loss: 5.8750e-04 - accuracy: 0.7996 - val_loss: 3.4112e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 490/500
# 24/25 [===========================>..] - ETA: 0s - loss: 5.9472e-04 - accuracy: 0.8094
# Epoch 490: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.9447e-04 - accuracy: 0.8068 - val_loss: 3.4090e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 491/500
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8661e-04 - accuracy: 0.7896
# Epoch 491: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 5.8765e-04 - accuracy: 0.7903 - val_loss: 3.4088e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 492/500
# 22/25 [=========================>....] - ETA: 0s - loss: 5.7962e-04 - accuracy: 0.7830
# Epoch 492: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.8031e-04 - accuracy: 0.7882 - val_loss: 3.4072e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 493/500
# 23/25 [==========================>...] - ETA: 0s - loss: 5.8092e-04 - accuracy: 0.8109
# Epoch 493: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.8370e-04 - accuracy: 0.8130 - val_loss: 3.4078e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 494/500
# 23/25 [==========================>...] - ETA: 0s - loss: 5.9506e-04 - accuracy: 0.7924
# Epoch 494: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.9434e-04 - accuracy: 0.7955 - val_loss: 3.4107e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 495/500
# 23/25 [==========================>...] - ETA: 0s - loss: 5.7671e-04 - accuracy: 0.8043
# Epoch 495: saving model to model_naive.h5
# 25/25 [==============================] - 1s 20ms/step - loss: 5.8188e-04 - accuracy: 0.8037 - val_loss: 3.4105e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 496/500
# 22/25 [=========================>....] - ETA: 0s - loss: 5.8915e-04 - accuracy: 0.8114
# Epoch 496: saving model to model_naive.h5
# 25/25 [==============================] - 0s 20ms/step - loss: 5.9047e-04 - accuracy: 0.8068 - val_loss: 3.4108e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 497/500
# 25/25 [==============================] - ETA: 0s - loss: 5.9418e-04 - accuracy: 0.8130
# Epoch 497: saving model to model_naive.h5
# 25/25 [==============================] - 0s 18ms/step - loss: 5.9418e-04 - accuracy: 0.8130 - val_loss: 3.4103e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 498/500
# 22/25 [=========================>....] - ETA: 0s - loss: 5.8824e-04 - accuracy: 0.7966
# Epoch 498: saving model to model_naive.h5
# 25/25 [==============================] - 0s 19ms/step - loss: 5.9316e-04 - accuracy: 0.7882 - val_loss: 3.4109e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 499/500
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8278e-04 - accuracy: 0.7969
# Epoch 499: saving model to model_naive.h5
# 25/25 [==============================] - 0s 20ms/step - loss: 5.8307e-04 - accuracy: 0.7986 - val_loss: 3.4116e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06
# Epoch 500/500
# 24/25 [===========================>..] - ETA: 0s - loss: 5.8912e-04 - accuracy: 0.8010
# Epoch 500: saving model to model_naive.h5
# 25/25 [==============================] - 1s 22ms/step - loss: 5.8861e-04 - accuracy: 0.8017 - val_loss: 3.4128e-04 - val_accuracy: 0.8515 - lr: 1.0000e-06

# %%
visualizacion_resultados(history_early)

# %%
print(history_early.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# load the saved model
model_phi.load_weights('model_naive.h5')

# %%
loss, accuracy = model_phi.evaluate(X_test_final, Y_test)
# Out:
# 19/19 [==============================] - 1s 31ms/step - loss: 2.6914e-04 - accuracy: 0.8579

# %%
phi_pred = model_phi.predict(X_test_final)
# Out:
# 19/19 [==============================] - 0s 4ms/step

# %%
phi_pred_true = inverse_min_max_scale(phi_pred, phi_min, phi_max)

# %%
phi_pred_true.shape
# Out:
# (605, 124)

# %%
depth = np.arange(0,124)

# %%
fig, ax = plt.subplots(1,4, figsize=(12, 8))
for i in range(0,4):
    well_number = np.random.randint(0,50)
    one_log_pred = phi_pred_true[well_number,:]
    one_log_true = phi_true[well_number,:]
    ax[i].plot(one_log_true, depth,label='Phie True')
    ax[i].plot(one_log_pred, depth, label='Phi pred')

    ax[i].invert_yaxis()  # This will flip the y-axis
    ax[i].set_title(f'well Number #{well_number}')
plt.legend()

plt.show()

# %%
fig.savefig("./plots/predictions.png")
