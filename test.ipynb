# %%
import numpy as np

# %%
Y_train = np.load('data_decatur/processed/train/porosity.npy')
Y_test = np.load('data_decatur/processed/test/porosity.npy')

# %%
np.ravel(np.min(Y_train))
# Out:
# array([-0.01045141])

# %%
np.ravel(np.min(Y_test))
# Out:
# array([-0.0046579])

# %%
Y_test[Y_test<0] = 0.0001
Y_train[Y_train<0] = 0.0001

# %%
np.ravel(np.min(Y_test))
# Out:
# array([0.])

# %%
np.ravel(np.min(Y_train))
# Out:
# array([1.09616667e-05])
